# %%
#------------------------------------------------------------------------------
#------------------------------------------------------------------------------

# %load_ext autoreload
# %autoreload 2


#------------------------------------------------------------------------------
#------------------------------------------------------------------------------

filename = "nn_s2areas_xy_train.py"
lst_args = [
    '-directory'       , '/project2/lgrandi/dbarge/pax_merge/temp_s2',
    '-max_dirs'        , '11',
    '-events_per_batch', '1000',
    '-downsample'      , '10'
]
str_args = " ".join(lst_args)

print("{0} {1}".format(filename, str_args))

# %run $filename $str_args
# %tb
# Out:
# nn_s2areas_xy_train.py -directory /project2/lgrandi/dbarge/pax_merge/temp_s2 -max_dirs 11 -events_per_batch 1000 -downsample 10
# Using TensorFlow backend.
# nn_s2waveforms_base.__init__()
# Input Directory:  /project2/lgrandi/dbarge/pax_merge/temp_s2
# Events:           10000
# Files:            11
# Files Train:      10
# Files Test:       1
# Train files:
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr0.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr1.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr2.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr3.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr4.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr5.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr6.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr7.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr8.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr9.npz
# Test files:
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr10.npz
# 10
# Devs:           [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11433862858590581464
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 472493965686048312
# physical_device_desc: "device: XLA_CPU device"
# ]
# Available GPUS: []
# Batches:          10
# Events per batch: 1000
# Events:           10000
#
# 10 Input files:
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr0.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr1.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr2.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr3.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr4.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr5.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr6.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr7.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr8.npz
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr9.npz
# Shuffling...
# Batches:          1
# Events per batch: 1000
# Events:           1000
#
# 1 Input files:
#    /project2/lgrandi/dbarge/pax_merge/temp_s2/strArr10.npz
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Add in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op LogicalNot in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Assert in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op RandomStandardNormal in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op RandomStandardNormal in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op RandomStandardNormal in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op RandomStandardNormal in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Start
# Executing op Reshape in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Epoch 1/10
#    (Data Generator) Batch: 4/10, File 4: strArr4.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 5/10, File 5: strArr5.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 2/10, File 2: strArr2.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 1/10, File 1: strArr1.npz, Memory: 0.3 GB
# /dali/lgrandi/dbarge/software/anaconda3/lib/python3.7/site-packages/keras/utils/data_utils.py:616: UserWarning: The input 0 could not be retrieved. It could be because a worker has died.
#   UserWarning)
#    (Data Generator) Batch: 7/10, File 7: strArr7.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 3/10, File 3: strArr3.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 9/10, File 9: strArr9.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 0/10, File 0: strArr0.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 6/10, File 6: strArr6.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 8/10, File 8: strArr8.npz, Memory: 0.4 GB
#    (Data Generator) Batch: 0/10, File 0: strArr0.npz, Memory: 0.6 GB
# Executing op __inference_keras_scratch_graph_2183 in device /job:localhost/replica:0/task:0/device:CPU:0
#  - 33s - loss: 286.1593 - acc: 0.7716
# Shuffling...
# Epoch 2/10
#    (Data Generator) Batch: 3/10, File 3: strArr3.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 7/10, File 7: strArr7.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 9/10, File 9: strArr9.npz, Memory: 0.3 GB
# Epoch 2/10
#    (Data Generator) Batch: 2/10, File 2: strArr2.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 6/10, File 6: strArr6.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 5/10, File 5: strArr5.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 8/10, File 8: strArr8.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 4/10, File 4: strArr4.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 1/10, File 1: strArr1.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 0/10, File 0: strArr0.npz, Memory: 0.3 GB
#  - 14s - loss: 214.9079 - acc: 0.9104
# Shuffling...
# Epoch 3/10
#    (Data Generator) Batch: 7/10, File 7: strArr7.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 8/10, File 8: strArr8.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 2/10, File 2: strArr2.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 0/10, File 0: strArr0.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 6/10, File 6: strArr6.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 3/10, File 3: strArr3.npz, Memory: 0.3 GB
# Epoch 3/10
#    (Data Generator) Batch: 5/10, File 5: strArr5.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 9/10, File 9: strArr9.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 1/10, File 1: strArr1.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 4/10, File 4: strArr4.npz, Memory: 0.3 GB
#  - 14s - loss: 173.0925 - acc: 0.9513
# Shuffling...
# Epoch 4/10
#    (Data Generator) Batch: 5/10, File 5: strArr5.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 6/10, File 6: strArr6.npz, Memory: 0.3 GB
# Epoch 4/10
#    (Data Generator) Batch: 1/10, File 1: strArr1.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 9/10, File 9: strArr9.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 0/10, File 0: strArr0.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 7/10, File 7: strArr7.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 8/10, File 8: strArr8.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 4/10, File 4: strArr4.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 2/10, File 2: strArr2.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 3/10, File 3: strArr3.npz, Memory: 0.3 GB
#  - 14s - loss: 163.7573 - acc: 0.9609
# Shuffling...
# Epoch 5/10
#    (Data Generator) Batch: 4/10, File 4: strArr4.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 6/10, File 6: strArr6.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 9/10, File 9: strArr9.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 2/10, File 2: strArr2.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 7/10, File 7: strArr7.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 3/10, File 3: strArr3.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 1/10, File 1: strArr1.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 8/10, File 8: strArr8.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 5/10, File 5: strArr5.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 0/10, File 0: strArr0.npz, Memory: 0.3 GB
#  - 14s - loss: 160.0484 - acc: 0.9677
# Shuffling...
# Epoch 6/10
#    (Data Generator) Batch: 0/10, File 0: strArr0.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 3/10, File 3: strArr3.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 6/10, File 6: strArr6.npz, Memory: 0.3 GB
# Epoch 6/10
#    (Data Generator) Batch: 5/10, File 5: strArr5.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 4/10, File 4: strArr4.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 9/10, File 9: strArr9.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 2/10, File 2: strArr2.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 8/10, File 8: strArr8.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 7/10, File 7: strArr7.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 1/10, File 1: strArr1.npz, Memory: 0.3 GB
#  - 14s - loss: 158.4435 - acc: 0.9712
# Shuffling...
# Epoch 7/10
#    (Data Generator) Batch: 5/10, File 5: strArr5.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 8/10, File 8: strArr8.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 9/10, File 9: strArr9.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 3/10, File 3: strArr3.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 1/10, File 1: strArr1.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 0/10, File 0: strArr0.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 6/10, File 6: strArr6.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 2/10, File 2: strArr2.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 7/10, File 7: strArr7.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 4/10, File 4: strArr4.npz, Memory: 0.3 GB
#  - 14s - loss: 157.2723 - acc: 0.9696
# Shuffling...
# Epoch 8/10
#    (Data Generator) Batch: 4/10, File 4: strArr4.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 8/10, File 8: strArr8.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 7/10, File 7: strArr7.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 0/10, File 0: strArr0.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 5/10, File 5: strArr5.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 9/10, File 9: strArr9.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 1/10, File 1: strArr1.npz, Memory: 0.3 GB
# Epoch 8/10
#    (Data Generator) Batch: 2/10, File 2: strArr2.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 6/10, File 6: strArr6.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 3/10, File 3: strArr3.npz, Memory: 0.3 GB
#  - 14s - loss: 156.0541 - acc: 0.9732
# Shuffling...
# Epoch 9/10
#    (Data Generator) Batch: 7/10, File 7: strArr7.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 1/10, File 1: strArr1.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 2/10, File 2: strArr2.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 5/10, File 5: strArr5.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 3/10, File 3: strArr3.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 0/10, File 0: strArr0.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 8/10, File 8: strArr8.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 4/10, File 4: strArr4.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 9/10, File 9: strArr9.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 6/10, File 6: strArr6.npz, Memory: 0.3 GB
#  - 15s - loss: 155.0276 - acc: 0.9727
# Shuffling...
# Epoch 10/10
#    (Data Generator) Batch: 8/10, File 8: strArr8.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 5/10, File 5: strArr5.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 0/10, File 0: strArr0.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 4/10, File 4: strArr4.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 6/10, File 6: strArr6.npz, Memory: 0.3 GB
# Epoch 10/10
#    (Data Generator) Batch: 2/10, File 2: strArr2.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 7/10, File 7: strArr7.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 9/10, File 9: strArr9.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 1/10, File 1: strArr1.npz, Memory: 0.3 GB
#    (Data Generator) Batch: 3/10, File 3: strArr3.npz, Memory: 0.3 GB
#  - 14s - loss: 153.8933 - acc: 0.9725
# Shuffling...
# Done
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 127)               16256
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               12800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 80)                8080
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 80)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 40)                3240
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 40)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                820
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 42
# =================================================================
# Total params: 41,238
# Trainable params: 41,238
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# ----- Validate -----
#    (Data Generator) Batch: 0/1, File 0: strArr10.npz, Memory: 0.6 GB, i0=0000, i1=1000, j0=00000, j1=01000
# Executing op __inference_keras_scratch_graph_2875 in device /job:localhost/replica:0/task:0/device:CPU:0
# Batches: 1
#
# Saving './models/nn_modl_acc97_evts10000_127-100-80-40-20-2.h5'...
# Saving './models/nn_pred_acc97_evts10000_127-100-80-40-20-2.npy'...
# Saving './models/nn_hist_acc97_evts10000_127-100-80-40-20-2.npy'...
#
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
#
# Done in 2.8 min
# No traceback available to show.
