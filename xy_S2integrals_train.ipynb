# %%
####################################################################################################
####################################################################################################

import sys
import os.path

import datetime
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd
#import seaborn as sns

from IPython.display import display
from IPython.display import Image

import tensorflow as tf

print (tf.__version__)

import keras
import keras.utils.vis_utils
from keras import backend as K
from keras import layers
from keras import regularizers
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers.normalization import BatchNormalization
from keras.models import load_model
from keras.models import Sequential
from keras.utils import plot_model

from xy_s2integrals_models import *
from helpers import *

sys.path.append(os.path.abspath("../"))
from pax_utils import s1s2_utils
# Out:
# 1.4.1
# Using TensorFlow backend.

# %%
####################################################################################################
####################################################################################################

file_all = "../pax_merge/merged/merged_all_1803031449.pkl"

df_all   = pd.read_pickle(file_all)
df_all   = df_all[df_all['intr_count'] == 1].reset_index(drop=True)


####################################################################################################
####################################################################################################

df_train_truth = df_all[:][['x', 'y']]

df_train_input = df_all.iloc[:, 22:]
df_train_input = df_all[:][s1s2_utils.getS2integralsDataFrameColumns()]


####################################################################################################
####################################################################################################

#checkTrainingData(df_train_input, df_train_truth)

# %%
##########################################################################################
##########################################################################################

lst_models = [
    Xenon1TPosRecMLP(),
    bargeModel()
]

# %%
##########################################################################################
##########################################################################################

for iModel in range(0, len(lst_models)):
    
    ######################################################################################
    ######################################################################################

    model, model_name = lst_models[iModel]
    
    
    ######################################################################################
    ######################################################################################

    epochs     = 10
    batch_size = 64
    verbose    = 1
    
    
    ######################################################################################
    # Fit Model
    ######################################################################################
    
    print()
    print("Model Summary:")
    model.summary()
    print()
    model.fit(df_train_input, df_train_truth, epochs=epochs, batch_size=batch_size, verbose=verbose)
    print("Training Complete!")

        
    ######################################################################################
    # Save Model
    ######################################################################################

    folder   = "models" + "/"    
    name     = 'model' + '_' + model_name + '_' + 'elu' #model.activation
    name_h5  = folder + name + ".h5"
    name_png = folder + name + ".png"

    model.save(name_h5, overwrite=True)
        
   
    ######################################################################################
    ######################################################################################

    plot_model(model, to_file=name_png, show_layer_names=True, show_shapes=True)
    
    Image(filename=name_png) 
    

    ######################################################################################
    ######################################################################################
    
    continue
# Out:
# Model Summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 127)               16256
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               12800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 80)                8080
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 80)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 40)                3240
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 40)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                820
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 42
# =================================================================
# Total params: 41,238
# Trainable params: 41,238
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 17982/17982 [==============================] - 9s 487us/step - loss: 66.9020
# Epoch 2/10
# 17982/17982 [==============================] - 4s 215us/step - loss: 3.2387
# Epoch 3/10
# 17982/17982 [==============================] - 4s 206us/step - loss: 1.6969
# Epoch 4/10
# 17982/17982 [==============================] - 4s 210us/step - loss: 1.5729
# Epoch 5/10
# 17982/17982 [==============================] - 4s 212us/step - loss: 1.4680
# Epoch 6/10
# 17982/17982 [==============================] - 3s 190us/step - loss: 1.4228
# Epoch 7/10
# 17982/17982 [==============================] - 3s 194us/step - loss: 1.4228
# Epoch 8/10
# 17982/17982 [==============================] - 4s 202us/step - loss: 1.3311
# Epoch 9/10
# 17982/17982 [==============================] - 3s 191us/step - loss: 1.3587
# Epoch 10/10
# 17982/17982 [==============================] - 4s 204us/step - loss: 1.3236
# Training Complete!
#
# Model Summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 127)               16256
# _________________________________________________________________
# dense_8 (Dense)              (None, 100)               12800
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 80)                8080
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 80)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 40)                3240
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 40)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 20)                820
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 42
# =================================================================
# Total params: 41,238
# Trainable params: 41,238
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/10
# 17982/17982 [==============================] - 7s 413us/step - loss: 73.4518
# Epoch 2/10
# 17982/17982 [==============================] - 4s 241us/step - loss: 7.1949
# Epoch 3/10
# 17982/17982 [==============================] - 3s 192us/step - loss: 3.6976
# Epoch 4/10
# 17982/17982 [==============================] - 4s 242us/step - loss: 2.8182
# Epoch 5/10
# 17982/17982 [==============================] - 4s 211us/step - loss: 2.4924
# Epoch 6/10
# 17982/17982 [==============================] - 3s 189us/step - loss: 2.2603
# Epoch 7/10
# 17982/17982 [==============================] - 5s 266us/step - loss: 2.1304
# Epoch 8/10
# 17982/17982 [==============================] - 3s 189us/step - loss: 1.9958
# Epoch 9/10
# 17982/17982 [==============================] - 3s 187us/step - loss: 1.9345
# Epoch 10/10
# 17982/17982 [==============================] - 3s 192us/step - loss: 1.8853
# Training Complete!
