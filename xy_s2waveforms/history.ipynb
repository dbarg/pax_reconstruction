# %%
# %matplotlib inline

####################################################################################################
####################################################################################################

import sys

import matplotlib.pyplot as plt

sys.path.append("/home/dbarge")
from keras_utils.history_utils import *


####################################################################################################
####################################################################################################


dir_hist = './sbatch/models/cpu/'

f_arr = [
    'dnn_s2waveforms-xy_ts0010_e10_mse_adam_ac9910_layers1270-1270-127-2_hist.json',
    'dnn_s2waveforms-xy_ts0010_e50_mse_adam_ac9942_layers1270-1270-127-2_hist.json',
    'dnn_s2waveforms-xy_ts0020_e10_mse_adam_ac5003_layers2540-2540-1270-127-2_hist.json'
]


w, h = 10, 5

f = plt.figure(figsize=(w, h))
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('Accuracy')
plt.legend(loc='lower right')
plt.ylim((0.95, 1))

for iFile, f_hist in enumerate(f_arr):
    
    f = dir_hist + f_hist

    print(f)
    
    json_data = open(f).read()
    dct       = json.loads(json_data)

    acc  = dct['acc']
    loss = dct['loss']
    
    plt.plot(acc, label='Training Accuracy %d' % iFile)

    plt.legend(loc="lower right")
    
    continue
# Out:
# /project/rcc/ivy2/jupyterhub/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# ./sbatch/models/cpu/dnn_s2waveforms-xy_ts0010_e10_mse_adam_ac9910_layers1270-1270-127-2_hist.json
# ./sbatch/models/cpu/dnn_s2waveforms-xy_ts0010_e50_mse_adam_ac9942_layers1270-1270-127-2_hist.json
# ./sbatch/models/cpu/dnn_s2waveforms-xy_ts0020_e10_mse_adam_ac5003_layers2540-2540-1270-127-2_hist.json
